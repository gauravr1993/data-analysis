# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = (14, 8)
# %matplotlib inline

# %%
data = pd.read_csv('matches.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
# id                 636 non-null int64
# season             636 non-null int64
# city               629 non-null object
# date               636 non-null object
# team1              636 non-null object
# team2              636 non-null object
# toss_winner        636 non-null object
# toss_decision      636 non-null object
# result             636 non-null object
# dl_applied         636 non-null int64
# winner             633 non-null object
# win_by_runs        636 non-null int64
# win_by_wickets     636 non-null int64
# player_of_match    633 non-null object
# venue              636 non-null object
# umpire1            635 non-null object
# umpire2            635 non-null object
# umpire3            0 non-null float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 59.7+ KB

# %%
data['city'].fillna('Dubai',inplace=True)

# %%
data['winner'].dropna()
data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
data['team2'] = data['team2'].replace('Rising Pune Supergiant','Rising Pune Supergiants')
data['team1'] = data['team1'].replace('Rising Pune Supergiant','Rising Pune Supergiants')
data['winner'] = data['winner'].replace('Rising Pune Supergiant','Rising Pune Supergiants')

# %%
total_matches = data['team2'].value_counts() + data['team1'].value_counts()

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Rising Pune Supergiants        15
# Gujarat Lions                  13
# Pune Warriors                  12
# Kochi Tuskers Kerala            6
# Name: winner, dtype: int64

# %%
win_percent = (data['winner'].value_counts() * 100)/total_matches
new_index = ['CSK','DC','DD','GL','KXIP','KTK','KKR','MI','PWI','RR','RPS','RCB','SRH']
win_percent.index = new_index
fig, ax = plt.subplots()
plt.title('Win Percentage of Teams')
fig.set_size_inches(15, 5)
sns.barplot(x=win_percent.index,y=win_percent.values)
for p in ax.patches:
    ax.annotate(str(round(p.get_height(),2)),(p.get_x() * 1.005, p.get_height() * 1.005),ha='left',fontsize=12)

# %%
width = 0.5
plt.figure(2)
fig, ax = plt.subplots()
plt.title('Highest Man of the Match Awards')
plt.yticks(np.arange(2,20,2))
fig.set_size_inches(15, 5)
MOM = data['player_of_match'].value_counts().nlargest(10)
sns.barplot(MOM.index,MOM.values,palette='deep')

# %%
data['win_method'] = ['Bat_First' if el != 0 else 'Bat_Second' for el in data['win_by_runs']]

# %%
grouped = data.groupby('winner')['win_method']
grouped.groups.keys()
# Out:
# dict_keys(['Chennai Super Kings', 'Deccan Chargers', 'Delhi Daredevils', 'Gujarat Lions', 'Kings XI Punjab', 'Kochi Tuskers Kerala', 'Kolkata Knight Riders', 'Mumbai Indians', 'Pune Warriors', 'Rajasthan Royals', 'Rising Pune Supergiants', 'Royal Challengers Bangalore', 'Sunrisers Hyderabad'])

# %%
ind = grouped.groups.keys()
new_ind = ['CSK','DC','DD','GL','KXIP','KTK','KKR','MI','PWI','RR','RPS','RCB','SRH']
x_arg = np.arange(len(ind))
Bat_First = []
Bat_Second = []
for el in ind:
    values = grouped.get_group(el).value_counts()
    Bat_Second.append(values.loc['Bat_Second'])
    if 'Bat_First' in values.index:
        Bat_First.append(values.loc['Bat_First'])
    else:
         Bat_First.append(0)

# %%
plt.figure(3)
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

width = 0.5
p1 = plt.bar(x_arg, Bat_First,width,color='#d62728')
p2 = plt.bar(x_arg, Bat_Second,width,
             bottom=Bat_First)
plt.ylabel('Scores')
plt.title('Bat First and Second Wins')
plt.xticks(x_arg,new_ind)
plt.legend((p1[0], p2[0]), ('Bat First', 'Bat Second'))

plt.show()

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08      Rising Pune Supergiants
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1      Rising Pune Supergiants       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 1  normal           0      Rising Pune Supergiants            0
# 2  normal           0        Kolkata Knight Riders            0
# 3  normal           0              Kings XI Punjab            0
# 4  normal           0  Royal Challengers Bangalore           15
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1               7       SPD Smith    Maharashtra Cricket Association Stadium
# 2              10         CA Lynn     Saurashtra Cricket Association Stadium
# 3               6      GJ Maxwell                     Holkar Cricket Stadium
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
#
#           umpire1        umpire2  umpire3  win_method
# 0     AY Dandekar       NJ Llong      NaN   Bat_First
# 1  A Nand Kishore         S Ravi      NaN  Bat_Second
# 2     Nitin Menon      CK Nandan      NaN  Bat_Second
# 3    AK Chaudhary  C Shamshuddin      NaN  Bat_Second
# 4             NaN            NaN      NaN   Bat_First

# %%
#win_group = data.groupby('winner')['win_by_runs']
#key = win_group.groups.keys()
#fig = plt.figure()
#fig.subplots_adjust(hspace=0.5, wspace=0.5)
#for i,j in zip(range(1,len(key)+1),key):
#    plt.subplot(7,2,i)
#    win_group.get_group(j).plot.line(figsize=(20,35),title=j)

# %%
df = pd.read_csv('deliveries.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150460 entries, 0 to 150459
# Data columns (total 21 columns):
# match_id            150460 non-null int64
# inning              150460 non-null int64
# batting_team        150460 non-null object
# bowling_team        150460 non-null object
# over                150460 non-null int64
# ball                150460 non-null int64
# batsman             150460 non-null object
# non_striker         150460 non-null object
# bowler              150460 non-null object
# is_super_over       150460 non-null int64
# wide_runs           150460 non-null int64
# bye_runs            150460 non-null int64
# legbye_runs         150460 non-null int64
# noball_runs         150460 non-null int64
# penalty_runs        150460 non-null int64
# batsman_runs        150460 non-null int64
# extra_runs          150460 non-null int64
# total_runs          150460 non-null int64
# player_dismissed    7438 non-null object
# dismissal_kind      7438 non-null object
# fielder             5369 non-null object
# dtypes: int64(13), object(8)
# memory usage: 19.5+ MB

# %%
#Top Run Getters in all season
top_batsman = df.groupby('batsman')['batsman_runs'].sum().nlargest(10)
plt.figure(4)
fig, ax = plt.subplots()
fig.set_size_inches(13, 5)
plt.title('Top Batsman')
plt.xlabel('Batsman')
plt.ylabel('Runs')
sns.barplot(x=top_batsman.index,y=top_batsman.values)

# %%
final_data = pd.merge(data,df,left_on='id',right_on='match_id')

# %%
#Top Batsman(Run Getters) in a Season
top_batsman_by_season = final_data.groupby(['batsman','season'])['batsman_runs'].sum().nlargest(10)
plt.figure(4)
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)
plt.title('Highest Run Getter in a Season')
plt.ylabel('Runs')
plt.xticks(rotation=45)
g = sns.barplot(x=top_batsman_by_season.index,y=top_batsman_by_season.values,palette='Reds_d')
#annotate axis = seaborn axis
for p in g.patches:
             ax.annotate("%d" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=12, color='gray', xytext=(0, 10),
                 textcoords='offset points')

# %%
new_df = final_data.groupby(['season','batsman']).agg({'batsman_runs':'sum'})
table = new_df.sort_values(by = 'batsman_runs', ascending = False)

# %%
table.groupby(level=0).head(1)
# Out:
#                      batsman_runs
# season batsman
# 2016   V Kohli                973
# 2013   MEK Hussey             733
# 2012   CH Gayle               733
# 2014   RV Uthappa             660
# 2017   DA Warner              641
# 2010   SR Tendulkar           618
# 2008   SE Marsh               616
# 2011   CH Gayle               608
# 2009   ML Hayden              572
# 2015   DA Warner              562

# %%
for index, value in new_df.items():
     print("Index : {}, Value : {}".format(index, value))
# Out:
# Index : ('A Ashish Reddy', 2012), Value : 35
# Index : ('A Ashish Reddy', 2013), Value : 125
# Index : ('A Ashish Reddy', 2015), Value : 73
# Index : ('A Ashish Reddy', 2016), Value : 47
# Index : ('A Chandila', 2012), Value : 0
# Index : ('A Chandila', 2013), Value : 4
# Index : ('A Chopra', 2008), Value : 42
# Index : ('A Chopra', 2009), Value : 11
# Index : ('A Choudhary', 2017), Value : 25
# Index : ('A Flintoff', 2009), Value : 62
# Index : ('A Kumble', 2008), Value : 13
# Index : ('A Kumble', 2009), Value : 16
# Index : ('A Kumble', 2010), Value : 6
# Index : ('A Mishra', 2008), Value : 37
# Index : ('A Mishra', 2009), Value : 26
# Index : ('A Mishra', 2010), Value : 39
# Index : ('A Mishra', 2011), Value : 68
# Index : ('A Mishra', 2012), Value : 16
# Index : ('A Mishra', 2013), Value : 89
# Index : ('A Mishra', 2014), Value : 4
# Index : ('A Mishra', 2015), Value : 8
# Index : ('A Mishra', 2016), Value : 4
# Index : ('A Mishra', 2017), Value : 49
# Index : ('A Mithun', 2010), Value : 5
# Index : ('A Mithun', 2011), Value : 27
# Index : ('A Mithun', 2013), Value : 2
# Index : ('A Mukund', 2008), Value : 0
# Index : ('A Mukund', 2013), Value : 19
# Index : ('A Nehra', 2008), Value : 3
# Index : ('A Nehra', 2009), Value : 1
# Index : ('A Nehra', 2010), Value : 23
# Index : ('A Nehra', 2012), Value : 11
# Index : ('A Nehra', 2013), Value : 1
# Index : ('A Nehra', 2015), Value : 1
# Index : ('A Nehra', 2016), Value : 1
# Index : ('A Singh', 2009), Value : 1
# Index : ('A Singh', 2011), Value : 1
# Index : ('A Singh', 2012), Value : 0
# Index : ('A Symonds', 2008), Value : 161
# Index : ('A Symonds', 2009), Value : 249
# Index : ('A Symonds', 2010), Value : 429
# Index : ('A Symonds', 2011), Value : 135
# Index : ('A Uniyal', 2010), Value : 4
# Index : ('A Zampa', 2016), Value : 0
# Index : ('A Zampa', 2017), Value : 5
# Index : ('AA Bilakhia', 2009), Value : 67
# Index : ('AA Bilakhia', 2010), Value : 2
# Index : ('AA Chavan', 2011), Value : 1
# Index : ('AA Chavan', 2012), Value : 11
# Index : ('AA Jhunjhunwala', 2010), Value : 183
# Index : ('AA Jhunjhunwala', 2011), Value : 10
# Index : ('AA Jhunjhunwala', 2012), Value : 24
# Index : ('AA Noffke', 2008), Value : 9
# Index : ('AB Agarkar', 2008), Value : 54
# Index : ('AB Agarkar', 2009), Value : 66
# Index : ('AB Agarkar', 2010), Value : 40
# Index : ('AB Agarkar', 2011), Value : 7
# Index : ('AB Agarkar', 2013), Value : 12
# Index : ('AB Barath', 2010), Value : 42
# Index : ('AB Dinda', 2008), Value : 2
# Index : ('AB Dinda', 2009), Value : 2
# Index : ('AB Dinda', 2010), Value : 0
# Index : ('AB Dinda', 2011), Value : 0
# Index : ('AB Dinda', 2012), Value : 2
# Index : ('AB Dinda', 2013), Value : 9
# Index : ('AB Dinda', 2014), Value : 4
# Index : ('AB Dinda', 2017), Value : 7
# Index : ('AB McDonald', 2009), Value : 3
# Index : ('AB McDonald', 2010), Value : 65
# Index : ('AB McDonald', 2011), Value : 8
# Index : ('AB McDonald', 2012), Value : 47
# Index : ('AB McDonald', 2013), Value : 0
# Index : ('AB de Villiers', 2008), Value : 95
# Index : ('AB de Villiers', 2009), Value : 465
# Index : ('AB de Villiers', 2010), Value : 111
# Index : ('AB de Villiers', 2011), Value : 312
# Index : ('AB de Villiers', 2012), Value : 319
# Index : ('AB de Villiers', 2013), Value : 373
# Index : ('AB de Villiers', 2014), Value : 395
# Index : ('AB de Villiers', 2015), Value : 513
# Index : ('AB de Villiers', 2016), Value : 687
# Index : ('AB de Villiers', 2017), Value : 216
# Index : ('AC Blizzard', 2011), Value : 120
# Index : ('AC Blizzard', 2012), Value : 0
# Index : ('AC Gilchrist', 2008), Value : 436
# Index : ('AC Gilchrist', 2009), Value : 495
# Index : ('AC Gilchrist', 2010), Value : 289
# Index : ('AC Gilchrist', 2011), Value : 383
# Index : ('AC Gilchrist', 2012), Value : 172
# Index : ('AC Gilchrist', 2013), Value : 294
# Index : ('AC Thomas', 2011), Value : 1
# Index : ('AC Thomas', 2012), Value : 19
# Index : ('AC Voges', 2010), Value : 181
# Index : ('AD Mascarenhas', 2008), Value : 9
# Index : ('AD Mascarenhas', 2009), Value : 39
# Index : ('AD Mascarenhas', 2010), Value : 12
# Index : ('AD Mascarenhas', 2012), Value : 14
# Index : ('AD Mascarenhas', 2013), Value : 5
# Index : ('AD Mathews', 2009), Value : 16
# Index : ('AD Mathews', 2010), Value : 233
# Index : ('AD Mathews', 2012), Value : 127
# Index : ('AD Mathews', 2013), Value : 172
# Index : ('AD Mathews', 2015), Value : 144
# Index : ('AD Mathews', 2017), Value : 32
# Index : ('AD Nath', 2016), Value : 20
# Index : ('AD Nath', 2017), Value : 0
# Index : ('AD Russell', 2012), Value : 47
# Index : ('AD Russell', 2013), Value : 11
# Index : ('AD Russell', 2014), Value : 2
# Index : ('AD Russell', 2015), Value : 326
# Index : ('AD Russell', 2016), Value : 188
# Index : ('AF Milne', 2017), Value : 7
# Index : ('AG Murtaza', 2011), Value : 2
# Index : ('AG Murtaza', 2012), Value : 3
# Index : ('AG Murtaza', 2013), Value : 5
# Index : ('AG Paunikar', 2010), Value : 0
# Index : ('AG Paunikar', 2011), Value : 49
# Index : ('AJ Finch', 2010), Value : 21
# Index : ('AJ Finch', 2011), Value : 47
# Index : ('AJ Finch', 2012), Value : 55
# Index : ('AJ Finch', 2013), Value : 456
# Index : ('AJ Finch', 2014), Value : 309
# Index : ('AJ Finch', 2015), Value : 23
# Index : ('AJ Finch', 2016), Value : 393
# Index : ('AJ Finch', 2017), Value : 300
# Index : ('AJ Tye', 2017), Value : 53
# Index : ('AL Menaria', 2011), Value : 180
# Index : ('AL Menaria', 2012), Value : 220
# Index : ('AL Menaria', 2013), Value : 1
# Index : ('AM Nayar', 2008), Value : 206
# Index : ('AM Nayar', 2009), Value : 193
# Index : ('AM Nayar', 2010), Value : 58
# Index : ('AM Nayar', 2011), Value : 61
# Index : ('AM Nayar', 2012), Value : 45
# Index : ('AM Nayar', 2013), Value : 66
# Index : ('AM Nayar', 2014), Value : 43
# Index : ('AM Rahane', 2008), Value : 4
# Index : ('AM Rahane', 2009), Value : 144
# Index : ('AM Rahane', 2011), Value : 120
# Index : ('AM Rahane', 2012), Value : 560
# Index : ('AM Rahane', 2013), Value : 488
# Index : ('AM Rahane', 2014), Value : 339
# Index : ('AM Rahane', 2015), Value : 540
# Index : ('AM Rahane', 2016), Value : 480
# Index : ('AM Rahane', 2017), Value : 382
# Index : ('AN Ahmed', 2010), Value : 4
# Index : ('AN Ahmed', 2011), Value : 18
# Index : ('AN Ahmed', 2014), Value : 4
# Index : ('AN Ahmed', 2015), Value : 10
# Index : ('AN Ghosh', 2009), Value : 7
# Index : ('AP Dole', 2010), Value : 34
# Index : ('AP Majumdar', 2012), Value : 87
# Index : ('AP Tare', 2010), Value : 50
# Index : ('AP Tare', 2013), Value : 123
# Index : ('AP Tare', 2014), Value : 126
# Index : ('AP Tare', 2015), Value : 14
# Index : ('AP Tare', 2016), Value : 8
# Index : ('AP Tare', 2017), Value : 18
# Index : ('AR Bawne', 2017), Value : 12
# Index : ('AR Patel', 2014), Value : 62
# Index : ('AR Patel', 2015), Value : 206
# Index : ('AR Patel', 2016), Value : 111
# Index : ('AR Patel', 2017), Value : 227
# Index : ('AS Rajpoot', 2013), Value : 2
# Index : ('AS Rajpoot', 2017), Value : 4
# Index : ('AS Raut', 2009), Value : 78
# Index : ('AS Raut', 2010), Value : 56
# Index : ('AS Raut', 2011), Value : 60
# Index : ('AS Yadav', 2008), Value : 49
# Index : ('AT Rayudu', 2010), Value : 356
# Index : ('AT Rayudu', 2011), Value : 395
# Index : ('AT Rayudu', 2012), Value : 333
# Index : ('AT Rayudu', 2013), Value : 265
# Index : ('AT Rayudu', 2014), Value : 361
# Index : ('AT Rayudu', 2015), Value : 281
# Index : ('AT Rayudu', 2016), Value : 334
# Index : ('AT Rayudu', 2017), Value : 91
# Index : ('AUK Pathan', 2011), Value : 33
# Index : ('AUK Pathan', 2012), Value : 6
# Index : ('Abdur Razzak', 2008), Value : 0
# Index : ('Anirudh Singh', 2010), Value : 63
# Index : ('Ankit Sharma', 2012), Value : 18
# Index : ('Ankit Sharma', 2014), Value : 34
# Index : ('Ankit Sharma', 2015), Value : 7
# Index : ('Ankit Sharma', 2016), Value : 3
# Index : ('Ankit Sharma', 2017), Value : 25
# Index : ('Ankit Soni', 2017), Value : 7
# Index : ('Anureet Singh', 2015), Value : 18
# Index : ('Anureet Singh', 2017), Value : 15
# Index : ('Azhar Mahmood', 2012), Value : 186
# Index : ('Azhar Mahmood', 2013), Value : 196
# Index : ('Azhar Mahmood', 2015), Value : 6
# Index : ('B Akhil', 2008), Value : 46
# Index : ('B Akhil', 2009), Value : 17
# Index : ('B Akhil', 2011), Value : 13
# Index : ('B Chipli', 2008), Value : 20
# Index : ('B Chipli', 2011), Value : 207
# Index : ('B Chipli', 2012), Value : 37
# Index : ('B Chipli', 2013), Value : 16
# Index : ('B Kumar', 2011), Value : 1
# Index : ('B Kumar', 2012), Value : 40
# Index : ('B Kumar', 2013), Value : 52
# Index : ('B Kumar', 2014), Value : 1
# Index : ('B Kumar', 2015), Value : 17
# Index : ('B Kumar', 2016), Value : 43
# Index : ('B Kumar', 2017), Value : 4
# Index : ('B Laughlin', 2013), Value : 4
# Index : ('B Lee', 2008), Value : 17
# Index : ('B Lee', 2009), Value : 28
# Index : ('B Lee', 2010), Value : 11
# Index : ('B Lee', 2011), Value : 5
# Index : ('B Lee', 2012), Value : 42
# Index : ('B Lee', 2013), Value : 21
# Index : ('B Sumanth', 2010), Value : 35
# Index : ('BA Bhatt', 2011), Value : 0
# Index : ('BA Bhatt', 2012), Value : 6
# Index : ('BA Stokes', 2017), Value : 316
# Index : ('BAW Mendis', 2009), Value : 0
# Index : ('BAW Mendis', 2010), Value : 1
# Index : ('BAW Mendis', 2013), Value : 2
# Index : ('BB McCullum', 2008), Value : 188
# Index : ('BB McCullum', 2009), Value : 286
# Index : ('BB McCullum', 2010), Value : 114
# Index : ('BB McCullum', 2011), Value : 357
# Index : ('BB McCullum', 2012), Value : 289
# Index : ('BB McCullum', 2013), Value : 6
# Index : ('BB McCullum', 2014), Value : 405
# Index : ('BB McCullum', 2015), Value : 436
# Index : ('BB McCullum', 2016), Value : 354
# Index : ('BB McCullum', 2017), Value : 320
# Index : ('BB Samantray', 2012), Value : 2
# Index : ('BB Samantray', 2013), Value : 123
# Index : ('BB Sran', 2016), Value : 4
# Index : ('BCJ Cutting', 2014), Value : 8
# Index : ('BCJ Cutting', 2016), Value : 65
# Index : ('BCJ Cutting', 2017), Value : 51
# Index : ('BE Hendricks', 2014), Value : 0
# Index : ('BE Hendricks', 2015), Value : 1
# Index : ('BJ Haddin', 2011), Value : 18
# Index : ('BJ Hodge', 2008), Value : 12
# Index : ('BJ Hodge', 2009), Value : 365
# Index : ('BJ Hodge', 2010), Value : 99
# Index : ('BJ Hodge', 2011), Value : 285
# Index : ('BJ Hodge', 2012), Value : 245
# Index : ('BJ Hodge', 2013), Value : 293
# Index : ('BJ Hodge', 2014), Value : 101
# Index : ('BJ Rohrer', 2013), Value : 193
# Index : ('BMAJ Mendis', 2013), Value : 23
# Index : ('BR Dunk', 2014), Value : 40
# Index : ('Basil Thampi', 2017), Value : 28
# Index : ('Bipul Sharma', 2010), Value : 9
# Index : ('Bipul Sharma', 2011), Value : 23
# Index : ('Bipul Sharma', 2012), Value : 72
# Index : ('Bipul Sharma', 2015), Value : 1
# Index : ('Bipul Sharma', 2016), Value : 51
# Index : ('Bipul Sharma', 2017), Value : 31
# Index : ('C Madan', 2010), Value : 15
# Index : ('C Munro', 2016), Value : 30
# Index : ('C Nanda', 2009), Value : 0
# Index : ('C de Grandhomme', 2017), Value : 126
# Index : ('CA Ingram', 2011), Value : 21
# Index : ('CA Lynn', 2012), Value : 6
# Index : ('CA Lynn', 2014), Value : 58
# Index : ('CA Lynn', 2016), Value : 25
# Index : ('CA Lynn', 2017), Value : 295
# Index : ('CA Pujara', 2010), Value : 122
# Index : ('CA Pujara', 2011), Value : 34
# Index : ('CA Pujara', 2012), Value : 17
# Index : ('CA Pujara', 2013), Value : 92
# Index : ('CA Pujara', 2014), Value : 125
# Index : ('CH Gayle', 2009), Value : 184
# Index : ('CH Gayle', 2010), Value : 292
# Index : ('CH Gayle', 2011), Value : 608
# Index : ('CH Gayle', 2012), Value : 733
# Index : ('CH Gayle', 2013), Value : 720
# Index : ('CH Gayle', 2014), Value : 196
# Index : ('CH Gayle', 2015), Value : 491
# Index : ('CH Gayle', 2016), Value : 227
# Index : ('CH Gayle', 2017), Value : 200
# Index : ('CH Morris', 2013), Value : 14
# Index : ('CH Morris', 2015), Value : 76
# Index : ('CH Morris', 2016), Value : 195
# Index : ('CH Morris', 2017), Value : 154
# Index : ('CJ Anderson', 2014), Value : 265
# Index : ('CJ Anderson', 2015), Value : 114
# Index : ('CJ Anderson', 2017), Value : 142
# Index : ('CJ Ferguson', 2011), Value : 48
# Index : ('CJ Ferguson', 2012), Value : 50
# Index : ('CJ Jordan', 2016), Value : 3
# Index : ('CJ Jordan', 2017), Value : 0
# Index : ('CJ McKay', 2012), Value : 8
# Index : ('CK Kapugedera', 2008), Value : 16
# Index : ('CK Langeveldt', 2010), Value : 0
# Index : ('CK Langeveldt', 2011), Value : 8
# Index : ('CL White', 2008), Value : 114
# Index : ('CL White', 2010), Value : 48
# Index : ('CL White', 2011), Value : 104
# Index : ('CL White', 2012), Value : 479
# Index : ('CL White', 2013), Value : 226
# Index : ('CM Gautam', 2013), Value : 44
# Index : ('CM Gautam', 2014), Value : 121
# Index : ('CM Gautam', 2015), Value : 4
# Index : ('CR Brathwaite', 2016), Value : 83
# Index : ('CR Brathwaite', 2017), Value : 12
# Index : ('CR Woakes', 2017), Value : 46
# Index : ('CRD Fernando', 2008), Value : 2
# Index : ('CRD Fernando', 2010), Value : 2
# Index : ('D Kalyankrishna', 2008), Value : 3
# Index : ('D Salunkhe', 2008), Value : 33
# Index : ('D Wiese', 2015), Value : 122
# Index : ('D Wiese', 2016), Value : 5
# Index : ('D du Preez', 2009), Value : 10
# Index : ('DA Miller', 2012), Value : 98
# Index : ('DA Miller', 2013), Value : 418
# Index : ('DA Miller', 2014), Value : 446
# Index : ('DA Miller', 2015), Value : 357
# Index : ('DA Miller', 2016), Value : 161
# Index : ('DA Miller', 2017), Value : 83
# Index : ('DA Warner', 2009), Value : 163
# Index : ('DA Warner', 2010), Value : 282
# Index : ('DA Warner', 2011), Value : 324
# Index : ('DA Warner', 2012), Value : 256
# Index : ('DA Warner', 2013), Value : 410
# Index : ('DA Warner', 2014), Value : 528
# Index : ('DA Warner', 2015), Value : 562
# Index : ('DA Warner', 2016), Value : 848
# Index : ('DA Warner', 2017), Value : 641
# Index : ('DAJ Bracewell', 2012), Value : 12
# Index : ('DB Das', 2008), Value : 103
# Index : ('DB Das', 2012), Value : 126
# Index : ('DB Das', 2013), Value : 75
# Index : ('DB Ravi Teja', 2008), Value : 109
# Index : ('DB Ravi Teja', 2009), Value : 65
# Index : ('DB Ravi Teja', 2011), Value : 183
# Index : ('DB Ravi Teja', 2012), Value : 4
# Index : ('DB Ravi Teja', 2013), Value : 14
# Index : ('DE Bollinger', 2010), Value : 18
# Index : ('DE Bollinger', 2011), Value : 0
# Index : ('DE Bollinger', 2012), Value : 3
# Index : ('DH Yagnik', 2011), Value : 16
# Index : ('DH Yagnik', 2012), Value : 25
# Index : ('DH Yagnik', 2013), Value : 125
# Index : ('DH Yagnik', 2014), Value : 4
# Index : ('DJ Bravo', 2008), Value : 178
# Index : ('DJ Bravo', 2009), Value : 218
# Index : ('DJ Bravo', 2010), Value : 61
# Index : ('DJ Bravo', 2011), Value : 11
# Index : ('DJ Bravo', 2012), Value : 371
# Index : ('DJ Bravo', 2013), Value : 121
# Index : ('DJ Bravo', 2014), Value : 8
# Index : ('DJ Bravo', 2015), Value : 195
# Index : ('DJ Bravo', 2016), Value : 99
# Index : ('DJ Harris', 2012), Value : 111
# Index : ('DJ Hooda', 2015), Value : 151
# Index : ('DJ Hooda', 2016), Value : 144
# Index : ('DJ Hooda', 2017), Value : 78
# Index : ('DJ Hussey', 2008), Value : 319
# Index : ('DJ Hussey', 2009), Value : 98
# Index : ('DJ Hussey', 2010), Value : 94
# Index : ('DJ Hussey', 2011), Value : 64
# Index : ('DJ Hussey', 2012), Value : 396
# Index : ('DJ Hussey', 2013), Value : 235
# Index : ('DJ Hussey', 2014), Value : 116
# Index : ('DJ Jacobs', 2011), Value : 92
# Index : ('DJ Jacobs', 2012), Value : 0
# Index : ('DJ Muthuswami', 2015), Value : 1
# Index : ('DJ Thornely', 2008), Value : 39
# Index : ('DJG Sammy', 2013), Value : 174
# Index : ('DJG Sammy', 2014), Value : 108
# Index : ('DJG Sammy', 2015), Value : 13
# Index : ('DL Chahar', 2017), Value : 14
# Index : ('DL Vettori', 2009), Value : 34
# Index : ('DL Vettori', 2010), Value : 33
# Index : ('DL Vettori', 2011), Value : 23
# Index : ('DL Vettori', 2012), Value : 31
# Index : ('DM Bravo', 2017), Value : 6
# Index : ('DNT Zoysa', 2008), Value : 11
# Index : ('DP Nannes', 2010), Value : 4
# Index : ('DP Vijaykumar', 2008), Value : 1
# Index : ('DPMD Jayawardene', 2008), Value : 179
# Index : ('DPMD Jayawardene', 2009), Value : 219
# Index : ('DPMD Jayawardene', 2010), Value : 445
# Index : ('DPMD Jayawardene', 2011), Value : 299
# Index : ('DPMD Jayawardene', 2012), Value : 335
# Index : ('DPMD Jayawardene', 2013), Value : 331
# Index : ('DR Martyn', 2010), Value : 19
# Index : ('DR Smith', 2008), Value : 45
# Index : ('DR Smith', 2009), Value : 215
# Index : ('DR Smith', 2010), Value : 22
# Index : ('DR Smith', 2012), Value : 157
# Index : ('DR Smith', 2013), Value : 418
# Index : ('DR Smith', 2014), Value : 566
# Index : ('DR Smith', 2015), Value : 399
# Index : ('DR Smith', 2016), Value : 324
# Index : ('DR Smith', 2017), Value : 239
# Index : ('DS Kulkarni', 2008), Value : 2
# Index : ('DS Kulkarni', 2009), Value : 9
# Index : ('DS Kulkarni', 2011), Value : 2
# Index : ('DS Kulkarni', 2012), Value : 10
# Index : ('DS Kulkarni', 2014), Value : 35
# Index : ('DS Kulkarni', 2015), Value : 4
# Index : ('DS Kulkarni', 2016), Value : 27
# Index : ('DS Kulkarni', 2017), Value : 1
# Index : ('DS Lehmann', 2008), Value : 18
# Index : ('DT Christian', 2011), Value : 190
# Index : ('DT Christian', 2012), Value : 145
# Index : ('DT Christian', 2013), Value : 6
# Index : ('DT Christian', 2017), Value : 79
# Index : ('DT Patil', 2008), Value : 13
# Index : ('DW Steyn', 2008), Value : 2
# Index : ('DW Steyn', 2009), Value : 0
# Index : ('DW Steyn', 2010), Value : 13
# Index : ('DW Steyn', 2011), Value : 36
# Index : ('DW Steyn', 2012), Value : 19
# Index : ('DW Steyn', 2013), Value : 53
# Index : ('DW Steyn', 2014), Value : 22
# Index : ('DW Steyn', 2015), Value : 20
# Index : ('DW Steyn', 2016), Value : 1
# Index : ('EJG Morgan', 2010), Value : 35
# Index : ('EJG Morgan', 2011), Value : 137
# Index : ('EJG Morgan', 2013), Value : 307
# Index : ('EJG Morgan', 2015), Value : 187
# Index : ('EJG Morgan', 2016), Value : 123
# Index : ('EJG Morgan', 2017), Value : 65
# Index : ('ER Dwivedi', 2016), Value : 24
# Index : ('F Behardien', 2016), Value : 14
# Index : ('F du Plessis', 2012), Value : 398
# Index : ('F du Plessis', 2014), Value : 303
# Index : ('F du Plessis', 2015), Value : 380
# Index : ('F du Plessis', 2016), Value : 206
# Index : ('F du Plessis', 2017), Value : 8
# Index : ('FH Edwards', 2009), Value : 4
# Index : ('FY Fazal', 2010), Value : 164
# Index : ('FY Fazal', 2011), Value : 19
# Index : ('G Gambhir', 2008), Value : 534
# Index : ('G Gambhir', 2009), Value : 286
# Index : ('G Gambhir', 2010), Value : 277
# Index : ('G Gambhir', 2011), Value : 378
# Index : ('G Gambhir', 2012), Value : 590
# Index : ('G Gambhir', 2013), Value : 406
# Index : ('G Gambhir', 2014), Value : 335
# Index : ('G Gambhir', 2015), Value : 327
# Index : ('G Gambhir', 2016), Value : 501
# Index : ('G Gambhir', 2017), Value : 498
# Index : ('GB Hogg', 2012), Value : 15
# Index : ('GB Hogg', 2015), Value : 7
# Index : ('GC Smith', 2008), Value : 441
# Index : ('GC Smith', 2009), Value : 212
# Index : ('GC Smith', 2010), Value : 44
# Index : ('GC Smith', 2011), Value : 42
# Index : ('GD McGrath', 2008), Value : 4
# Index : ('GH Vihari', 2013), Value : 241
# Index : ('GH Vihari', 2015), Value : 39
# Index : ('GJ Bailey', 2009), Value : 45
# Index : ('GJ Bailey', 2010), Value : 18
# Index : ('GJ Bailey', 2014), Value : 257
# Index : ('GJ Bailey', 2015), Value : 259
# Index : ('GJ Bailey', 2016), Value : 84
# Index : ('GJ Maxwell', 2012), Value : 6
# Index : ('GJ Maxwell', 2013), Value : 36
# Index : ('GJ Maxwell', 2014), Value : 552
# Index : ('GJ Maxwell', 2015), Value : 146
# Index : ('GJ Maxwell', 2016), Value : 179
# Index : ('GJ Maxwell', 2017), Value : 310
# Index : ('GR Napier', 2009), Value : 15
# Index : ('Gurkeerat Singh', 2012), Value : 86
# Index : ('Gurkeerat Singh', 2013), Value : 108
# Index : ('Gurkeerat Singh', 2015), Value : 35
# Index : ('Gurkeerat Singh', 2016), Value : 113
# Index : ('H Das', 2008), Value : 2
# Index : ('HH Gibbs', 2008), Value : 167
# Index : ('HH Gibbs', 2009), Value : 371
# Index : ('HH Gibbs', 2010), Value : 267
# Index : ('HH Gibbs', 2012), Value : 81
# Index : ('HH Pandya', 2015), Value : 112
# Index : ('HH Pandya', 2016), Value : 44
# Index : ('HH Pandya', 2017), Value : 250
# Index : ('HM Amla', 2016), Value : 157
# Index : ('HM Amla', 2017), Value : 420
# Index : ('HV Patel', 2012), Value : 15
# Index : ('HV Patel', 2014), Value : 13
# Index : ('HV Patel', 2015), Value : 19
# Index : ('Harbhajan Singh', 2008), Value : 30
# Index : ('Harbhajan Singh', 2009), Value : 84
# Index : ('Harbhajan Singh', 2010), Value : 105
# Index : ('Harbhajan Singh', 2011), Value : 103
# Index : ('Harbhajan Singh', 2012), Value : 108
# Index : ('Harbhajan Singh', 2013), Value : 116
# Index : ('Harbhajan Singh', 2014), Value : 28
# Index : ('Harbhajan Singh', 2015), Value : 117
# Index : ('Harbhajan Singh', 2016), Value : 92
# Index : ('Harbhajan Singh', 2017), Value : 16
# Index : ('Harmeet Singh', 2010), Value : 0
# Index : ('Harmeet Singh', 2012), Value : 15
# Index : ('Harmeet Singh', 2013), Value : 3
# Index : ('Harpreet Singh', 2011), Value : 14
# Index : ('Harpreet Singh', 2012), Value : 6
# Index : ('I Malhotra', 2011), Value : 7
# Index : ('I Sharma', 2008), Value : 11
# Index : ('I Sharma', 2009), Value : 16
# Index : ('I Sharma', 2010), Value : 6
# Index : ('I Sharma', 2011), Value : 4
# Index : ('I Sharma', 2017), Value : 8
# Index : ('IC Pandey', 2013), Value : 0
# Index : ('IK Pathan', 2008), Value : 131
# Index : ('IK Pathan', 2009), Value : 196
# Index : ('IK Pathan', 2010), Value : 276
# Index : ('IK Pathan', 2011), Value : 150
# Index : ('IK Pathan', 2012), Value : 176
# Index : ('IK Pathan', 2013), Value : 153
# Index : ('IK Pathan', 2014), Value : 55
# Index : ('IK Pathan', 2016), Value : 11
# Index : ('IK Pathan', 2017), Value : 2
# Index : ('IR Jaggi', 2011), Value : 28
# Index : ('IR Jaggi', 2012), Value : 15
# Index : ('IR Jaggi', 2017), Value : 33
# Index : ('Imran Tahir', 2014), Value : 8
# Index : ('Imran Tahir', 2015), Value : 5
# Index : ('Imran Tahir', 2016), Value : 5
# Index : ('Imran Tahir', 2017), Value : 0
# Index : ('Iqbal Abdulla', 2008), Value : 1
# Index : ('Iqbal Abdulla', 2010), Value : 0
# Index : ('Iqbal Abdulla', 2011), Value : 15
# Index : ('Iqbal Abdulla', 2012), Value : 2
# Index : ('Iqbal Abdulla', 2013), Value : 8
# Index : ('Iqbal Abdulla', 2015), Value : 20
# Index : ('Iqbal Abdulla', 2016), Value : 37
# Index : ('Iqbal Abdulla', 2017), Value : 5
# Index : ('Ishan Kishan', 2016), Value : 42
# Index : ('Ishan Kishan', 2017), Value : 277
# Index : ('J Arunkumar', 2008), Value : 23
# Index : ('J Botha', 2009), Value : 47
# Index : ('J Botha', 2011), Value : 230
# Index : ('J Botha', 2012), Value : 58
# Index : ('J Botha', 2013), Value : 43
# Index : ('J Botha', 2015), Value : 31
# Index : ('J Suchith', 2015), Value : 48
# Index : ('J Syed Mohammad', 2011), Value : 15
# Index : ('J Syed Mohammad', 2012), Value : 4
# Index : ('J Syed Mohammad', 2013), Value : 10
# Index : ('J Theron', 2010), Value : 2
# Index : ('J Theron', 2012), Value : 7
# Index : ('J Theron', 2015), Value : 1
# Index : ('J Yadav', 2016), Value : 6
# Index : ('JA Morkel', 2008), Value : 241
# Index : ('JA Morkel', 2009), Value : 97
# Index : ('JA Morkel', 2010), Value : 199
# Index : ('JA Morkel', 2011), Value : 138
# Index : ('JA Morkel', 2012), Value : 107
# Index : ('JA Morkel', 2013), Value : 46
# Index : ('JA Morkel', 2014), Value : 45
# Index : ('JA Morkel', 2015), Value : 86
# Index : ('JA Morkel', 2016), Value : 16
# Index : ('JC Buttler', 2016), Value : 255
# Index : ('JC Buttler', 2017), Value : 273
# Index : ('JD Ryder', 2009), Value : 56
# Index : ('JD Ryder', 2011), Value : 292
# Index : ('JD Ryder', 2012), Value : 256
# Index : ('JD Unadkat', 2013), Value : 2
# Index : ('JD Unadkat', 2014), Value : 1
# Index : ('JD Unadkat', 2017), Value : 2
# Index : ('JDP Oram', 2008), Value : 18
# Index : ('JDP Oram', 2009), Value : 88
# Index : ('JDP Oram', 2011), Value : 0
# Index : ('JDS Neesham', 2014), Value : 42
# Index : ('JE Taylor', 2011), Value : 3
# Index : ('JEC Franklin', 2011), Value : 107
# Index : ('JEC Franklin', 2012), Value : 220
# Index : ('JH Kallis', 2008), Value : 199
# Index : ('JH Kallis', 2009), Value : 361
# Index : ('JH Kallis', 2010), Value : 572
# Index : ('JH Kallis', 2011), Value : 424
# Index : ('JH Kallis', 2012), Value : 409
# Index : ('JH Kallis', 2013), Value : 311
# Index : ('JH Kallis', 2014), Value : 151
# Index : ('JJ Bumrah', 2014), Value : 1
# Index : ('JJ Bumrah', 2016), Value : 8
# Index : ('JJ Bumrah', 2017), Value : 16
# Index : ('JJ Roy', 2017), Value : 59
# Index : ('JJ van der Wath', 2011), Value : 18
# Index : ('JM Kemp', 2010), Value : 26
# Index : ('JO Holder', 2014), Value : 16
# Index : ('JO Holder', 2016), Value : 22
# Index : ('JP Duminy', 2009), Value : 372
# Index : ('JP Duminy', 2010), Value : 157
# Index : ('JP Duminy', 2011), Value : 205
# Index : ('JP Duminy', 2012), Value : 244
# Index : ('JP Duminy', 2014), Value : 410
# Index : ('JP Duminy', 2015), Value : 414
# Index : ('JP Duminy', 2016), Value : 191
# Index : ('JP Faulkner', 2012), Value : 14
# Index : ('JP Faulkner', 2013), Value : 57
# Index : ('JP Faulkner', 2014), Value : 181
# Index : ('JP Faulkner', 2015), Value : 144
# Index : ('JP Faulkner', 2016), Value : 77
# Index : ('JP Faulkner', 2017), Value : 54
# Index : ('JR Hopes', 2008), Value : 221
# Index : ('JR Hopes', 2011), Value : 196
# Index : ('Jaskaran Singh', 2010), Value : 8
# Index : ('Joginder Sharma', 2008), Value : 16
# Index : ('Joginder Sharma', 2009), Value : 20
# Index : ('Joginder Sharma', 2011), Value : 0
# Index : ('K Goel', 2008), Value : 76
# Index : ('K Goel', 2009), Value : 124
# Index : ('K Goel', 2010), Value : 18
# Index : ('K Rabada', 2017), Value : 55
# Index : ('K Upadhyay', 2012), Value : 11
# Index : ('K Upadhyay', 2013), Value : 1
# Index : ('KA Pollard', 2010), Value : 273
# Index : ('KA Pollard', 2011), Value : 146
# Index : ('KA Pollard', 2012), Value : 220
# Index : ('KA Pollard', 2013), Value : 420
# Index : ('KA Pollard', 2014), Value : 273
# Index : ('KA Pollard', 2015), Value : 419
# Index : ('KA Pollard', 2016), Value : 208
# Index : ('KA Pollard', 2017), Value : 395
# Index : ('KAJ Roach', 2010), Value : 10
# Index : ('KB Arun Karthik', 2010), Value : 3
# Index : ('KB Arun Karthik', 2011), Value : 7
# Index : ('KB Arun Karthik', 2013), Value : 41
# Index : ('KC Cariappa', 2016), Value : 13
# Index : ('KC Cariappa', 2017), Value : 2
# Index : ('KC Sangakkara', 2008), Value : 320
# Index : ('KC Sangakkara', 2009), Value : 332
# Index : ('KC Sangakkara', 2010), Value : 357
# Index : ('KC Sangakkara', 2011), Value : 358
# Index : ('KC Sangakkara', 2012), Value : 200
# Index : ('KC Sangakkara', 2013), Value : 120
# Index : ('KD Karthik', 2008), Value : 145
# Index : ('KD Karthik', 2009), Value : 288
# Index : ('KD Karthik', 2010), Value : 278
# Index : ('KD Karthik', 2011), Value : 282
# Index : ('KD Karthik', 2012), Value : 238
# Index : ('KD Karthik', 2013), Value : 510
# Index : ('KD Karthik', 2014), Value : 325
# Index : ('KD Karthik', 2015), Value : 141
# Index : ('KD Karthik', 2016), Value : 335
# Index : ('KD Karthik', 2017), Value : 361
# Index : ('KH Pandya', 2016), Value : 237
# Index : ('KH Pandya', 2017), Value : 243
# Index : ('KJ Abbott', 2016), Value : 13
# Index : ('KK Cooper', 2012), Value : 38
# Index : ('KK Cooper', 2013), Value : 39
# Index : ('KK Cooper', 2014), Value : 39
# Index : ('KK Nair', 2013), Value : 9
# Index : ('KK Nair', 2014), Value : 330
# Index : ('KK Nair', 2015), Value : 181
# Index : ('KK Nair', 2016), Value : 357
# Index : ('KK Nair', 2017), Value : 281
# Index : ('KL Rahul', 2013), Value : 20
# Index : ('KL Rahul', 2014), Value : 166
# Index : ('KL Rahul', 2015), Value : 142
# Index : ('KL Rahul', 2016), Value : 397
# Index : ('KM Jadhav', 2010), Value : 76
# Index : ('KM Jadhav', 2011), Value : 18
# Index : ('KM Jadhav', 2013), Value : 152
# Index : ('KM Jadhav', 2014), Value : 149
# Index : ('KM Jadhav', 2015), Value : 189
# Index : ('KM Jadhav', 2016), Value : 42
# Index : ('KM Jadhav', 2017), Value : 267
# Index : ('KMDN Kulasekara', 2012), Value : 5
# Index : ('KP Appanna', 2009), Value : 0
# Index : ('KP Appanna', 2010), Value : 2
# Index : ('KP Pietersen', 2009), Value : 93
# Index : ('KP Pietersen', 2010), Value : 236
# Index : ('KP Pietersen', 2012), Value : 305
# Index : ('KP Pietersen', 2014), Value : 294
# Index : ('KP Pietersen', 2016), Value : 73
# Index : ('KS Williamson', 2015), Value : 31
# Index : ('KS Williamson', 2016), Value : 124
# Index : ('KS Williamson', 2017), Value : 256
# Index : ('KV Sharma', 2009), Value : 1
# Index : ('KV Sharma', 2013), Value : 85
# Index : ('KV Sharma', 2014), Value : 42
# Index : ('KV Sharma', 2015), Value : 104
# Index : ('KV Sharma', 2016), Value : 36
# Index : ('KV Sharma', 2017), Value : 49
# Index : ('KW Richardson', 2013), Value : 34
# Index : ('KW Richardson', 2014), Value : 1
# Index : ('KW Richardson', 2016), Value : 1
# Index : ('Kamran Akmal', 2008), Value : 128
# Index : ('Kamran Khan', 2009), Value : 3
# Index : ('Karanveer Singh', 2014), Value : 1
# Index : ('Karanveer Singh', 2015), Value : 11
# Index : ('Kuldeep Yadav', 2017), Value : 20
# Index : ('L Ablish', 2011), Value : 0
# Index : ('L Balaji', 2008), Value : 0
# Index : ('L Balaji', 2009), Value : 4
# Index : ('L Balaji', 2010), Value : 18
# Index : ('L Balaji', 2011), Value : 4
# Index : ('L Balaji', 2013), Value : 9
# Index : ('L Balaji', 2014), Value : 1
# Index : ('L Ronchi', 2008), Value : 34
# Index : ('L Ronchi', 2009), Value : 0
# Index : ('LA Carseldine', 2009), Value : 81
# Index : ('LA Pomersbach', 2008), Value : 152
# Index : ('LA Pomersbach', 2009), Value : 41
# Index : ('LA Pomersbach', 2011), Value : 51
# Index : ('LA Pomersbach', 2013), Value : 58
# Index : ('LH Ferguson', 2017), Value : 1
# Index : ('LJ Wright', 2013), Value : 106
# Index : ('LMP Simmons', 2014), Value : 394
# Index : ('LMP Simmons', 2015), Value : 540
# Index : ('LMP Simmons', 2016), Value : 8
# Index : ('LMP Simmons', 2017), Value : 137
# Index : ('LPC Silva', 2008), Value : 40
# Index : ('LR Shukla', 2008), Value : 163
# Index : ('LR Shukla', 2009), Value : 83
# Index : ('LR Shukla', 2010), Value : 36
# Index : ('LR Shukla', 2011), Value : 14
# Index : ('LR Shukla', 2012), Value : 75
# Index : ('LR Shukla', 2013), Value : 3
# Index : ('LR Shukla', 2014), Value : 31
# Index : ('LRPL Taylor', 2008), Value : 149
# Index : ('LRPL Taylor', 2009), Value : 280
# Index : ('LRPL Taylor', 2010), Value : 88
# Index : ('LRPL Taylor', 2011), Value : 181
# Index : ('LRPL Taylor', 2012), Value : 197
# Index : ('LRPL Taylor', 2013), Value : 63
# Index : ('LRPL Taylor', 2014), Value : 59
# Index : ('M Ashwin', 2016), Value : 0
# Index : ('M Kaif', 2008), Value : 176
# Index : ('M Kaif', 2010), Value : 28
# Index : ('M Kaif', 2011), Value : 41
# Index : ('M Kaif', 2012), Value : 14
# Index : ('M Kartik', 2008), Value : 30
# Index : ('M Kartik', 2009), Value : 21
# Index : ('M Kartik', 2010), Value : 22
# Index : ('M Kartik', 2011), Value : 12
# Index : ('M Kartik', 2012), Value : 26
# Index : ('M Kartik', 2013), Value : 2
# Index : ('M Klinger', 2011), Value : 73
# Index : ('M Manhas', 2009), Value : 75
# Index : ('M Manhas', 2010), Value : 157
# Index : ('M Manhas', 2011), Value : 114
# Index : ('M Manhas', 2012), Value : 120
# Index : ('M Manhas', 2013), Value : 13
# Index : ('M Manhas', 2014), Value : 35
# Index : ('M Morkel', 2009), Value : 8
# Index : ('M Morkel', 2010), Value : 9
# Index : ('M Morkel', 2011), Value : 40
# Index : ('M Morkel', 2012), Value : 3
# Index : ('M Morkel', 2013), Value : 57
# Index : ('M Morkel', 2014), Value : 4
# Index : ('M Morkel', 2015), Value : 4
# Index : ('M Morkel', 2016), Value : 1
# Index : ('M Muralitharan', 2008), Value : 0
# Index : ('M Muralitharan', 2009), Value : 8
# Index : ('M Muralitharan', 2010), Value : 1
# Index : ('M Muralitharan', 2011), Value : 5
# Index : ('M Muralitharan', 2012), Value : 6
# Index : ('M Ntini', 2008), Value : 11
# Index : ('M Rawat', 2008), Value : 34
# Index : ('M Rawat', 2009), Value : 16
# Index : ('M Rawat', 2013), Value : 5
# Index : ('M Vijay', 2009), Value : 60
# Index : ('M Vijay', 2010), Value : 458
# Index : ('M Vijay', 2011), Value : 434
# Index : ('M Vijay', 2012), Value : 336
# Index : ('M Vijay', 2013), Value : 312
# Index : ('M Vijay', 2014), Value : 207
# Index : ('M Vijay', 2015), Value : 251
# Index : ('M Vijay', 2016), Value : 453
# Index : ('M Vohra', 2013), Value : 161
# Index : ('M Vohra', 2014), Value : 324
# Index : ('M Vohra', 2015), Value : 82
# Index : ('M Vohra', 2016), Value : 161
# Index : ('M Vohra', 2017), Value : 229
# Index : ('M de Lange', 2014), Value : 1
# Index : ('MA Agarwal', 2011), Value : 141
# Index : ('MA Agarwal', 2012), Value : 225
# Index : ('MA Agarwal', 2013), Value : 67
# Index : ('MA Agarwal', 2014), Value : 115
# Index : ('MA Agarwal', 2015), Value : 213
# Index : ('MA Agarwal', 2016), Value : 27
# Index : ('MA Agarwal', 2017), Value : 26
# Index : ('MA Khote', 2008), Value : 24
# Index : ('MA Starc', 2014), Value : 85
# Index : ('MA Starc', 2015), Value : 11
# Index : ('MC Henriques', 2009), Value : 38
# Index : ('MC Henriques', 2010), Value : 11
# Index : ('MC Henriques', 2013), Value : 165
# Index : ('MC Henriques', 2014), Value : 9
# Index : ('MC Henriques', 2015), Value : 287
# Index : ('MC Henriques', 2016), Value : 182
# Index : ('MC Henriques', 2017), Value : 277
# Index : ('MC Juneja', 2013), Value : 125
# Index : ('MD Mishra', 2010), Value : 166
# Index : ('MD Mishra', 2011), Value : 67
# Index : ('MD Mishra', 2012), Value : 4
# Index : ('MDKJ Perera', 2013), Value : 14
# Index : ('MEK Hussey', 2008), Value : 168
# Index : ('MEK Hussey', 2010), Value : 37
# Index : ('MEK Hussey', 2011), Value : 492
# Index : ('MEK Hussey', 2012), Value : 261
# Index : ('MEK Hussey', 2013), Value : 733
# Index : ('MEK Hussey', 2014), Value : 209
# Index : ('MEK Hussey', 2015), Value : 77
# Index : ('MF Maharoof', 2008), Value : 125
# Index : ('MF Maharoof', 2009), Value : 21
# Index : ('MF Maharoof', 2010), Value : 31
# Index : ('MG Johnson', 2013), Value : 39
# Index : ('MG Johnson', 2014), Value : 56
# Index : ('MG Johnson', 2015), Value : 31
# Index : ('MG Johnson', 2016), Value : 5
# Index : ('MG Johnson', 2017), Value : 20
# Index : ('MJ Clarke', 2012), Value : 98
# Index : ('MJ Guptill', 2016), Value : 57
# Index : ('MJ Guptill', 2017), Value : 132
# Index : ('MJ Lumb', 2010), Value : 278
# Index : ('MJ Lumb', 2011), Value : 0
# Index : ('MJ McClenaghan', 2015), Value : 13
# Index : ('MJ McClenaghan', 2016), Value : 34
# Index : ('MJ McClenaghan', 2017), Value : 16
# Index : ('MK Pandey', 2008), Value : 3
# Index : ('MK Pandey', 2009), Value : 168
# Index : ('MK Pandey', 2010), Value : 249
# Index : ('MK Pandey', 2011), Value : 246
# Index : ('MK Pandey', 2012), Value : 143
# Index : ('MK Pandey', 2013), Value : 136
# Index : ('MK Pandey', 2014), Value : 409
# Index : ('MK Pandey', 2015), Value : 225
# Index : ('MK Pandey', 2016), Value : 248
# Index : ('MK Pandey', 2017), Value : 396
# Index : ('MK Tiwary', 2008), Value : 104
# Index : ('MK Tiwary', 2009), Value : 9
# Index : ('MK Tiwary', 2010), Value : 237
# Index : ('MK Tiwary', 2011), Value : 359
# Index : ('MK Tiwary', 2012), Value : 260
# Index : ('MK Tiwary', 2013), Value : 146
# Index : ('MK Tiwary', 2014), Value : 152
# Index : ('MK Tiwary', 2015), Value : 57
# Index : ('MK Tiwary', 2017), Value : 324
# Index : ('ML Hayden', 2008), Value : 189
# Index : ('ML Hayden', 2009), Value : 572
# Index : ('ML Hayden', 2010), Value : 346
# Index : ('MM Patel', 2008), Value : 0
# Index : ('MM Patel', 2009), Value : 33
# Index : ('MM Patel', 2010), Value : 4
# Index : ('MM Patel', 2011), Value : 0
# Index : ('MM Patel', 2012), Value : 2
# Index : ('MM Patel', 2017), Value : 0
# Index : ('MM Sharma', 2013), Value : 0
# Index : ('MM Sharma', 2014), Value : 1
# Index : ('MM Sharma', 2015), Value : 28
# Index : ('MM Sharma', 2016), Value : 32
# Index : ('MM Sharma', 2017), Value : 51
# Index : ('MN Samuels', 2012), Value : 124
# Index : ('MN Samuels', 2013), Value : 8
# Index : ('MN Samuels', 2017), Value : 29
# Index : ('MN van Wyk', 2009), Value : 167
# Index : ('MP Stoinis', 2016), Value : 146
# Index : ('MP Stoinis', 2017), Value : 17
# Index : ('MR Marsh', 2010), Value : 28
# Index : ('MR Marsh', 2011), Value : 50
# Index : ('MR Marsh', 2013), Value : 140
# Index : ('MR Marsh', 2016), Value : 7
# Index : ('MS Bisla', 2010), Value : 218
# Index : ('MS Bisla', 2011), Value : 72
# Index : ('MS Bisla', 2012), Value : 213
# Index : ('MS Bisla', 2013), Value : 255
# Index : ('MS Bisla', 2014), Value : 3
# Index : ('MS Bisla', 2015), Value : 37
# Index : ('MS Dhoni', 2008), Value : 414
# Index : ('MS Dhoni', 2009), Value : 332
# Index : ('MS Dhoni', 2010), Value : 287
# Index : ('MS Dhoni', 2011), Value : 392
# Index : ('MS Dhoni', 2012), Value : 357
# Index : ('MS Dhoni', 2013), Value : 461
# Index : ('MS Dhoni', 2014), Value : 371
# Index : ('MS Dhoni', 2015), Value : 372
# Index : ('MS Dhoni', 2016), Value : 284
# Index : ('MS Dhoni', 2017), Value : 290
# Index : ('MS Gony', 2008), Value : 35
# Index : ('MS Gony', 2009), Value : 13
# Index : ('MS Gony', 2010), Value : 2
# Index : ('MS Gony', 2011), Value : 0
# Index : ('MS Gony', 2012), Value : 4
# Index : ('MS Gony', 2013), Value : 45
# Index : ('MS Wade', 2011), Value : 22
# Index : ('MV Boucher', 2008), Value : 225
# Index : ('MV Boucher', 2009), Value : 150
# Index : ('MV Boucher', 2010), Value : 13
# Index : ('MV Boucher', 2011), Value : 6
# Index : ('Mandeep Singh', 2010), Value : 4
# Index : ('Mandeep Singh', 2011), Value : 47
# Index : ('Mandeep Singh', 2012), Value : 432
# Index : ('Mandeep Singh', 2013), Value : 260
# Index : ('Mandeep Singh', 2014), Value : 24
# Index : ('Mandeep Singh', 2015), Value : 157
# Index : ('Mandeep Singh', 2017), Value : 188
# Index : ('Mashrafe Mortaza', 2009), Value : 2
# Index : ('Misbah-ul-Haq', 2008), Value : 117
# Index : ('Mohammad Ashraful', 2009), Value : 2
# Index : ('Mohammad Asif', 2008), Value : 3
# Index : ('Mohammad Hafeez', 2008), Value : 64
# Index : ('Mohammad Nabi', 2017), Value : 2
# Index : ('Mohammed Shami', 2013), Value : 5
# Index : ('Mohammed Shami', 2014), Value : 3
# Index : ('Mohammed Shami', 2016), Value : 2
# Index : ('Mohammed Shami', 2017), Value : 36
# Index : ('N Rana', 2016), Value : 104
# Index : ('N Rana', 2017), Value : 333
# Index : ('N Saini', 2012), Value : 140
# Index : ('ND Doshi', 2011), Value : 0
# Index : ('NJ Maddinson', 2014), Value : 16
# Index : ('NJ Maddinson', 2015), Value : 4
# Index : ('NJ Rimmington', 2011), Value : 1
# Index : ('NL McCullum', 2011), Value : 26
# Index : ('NLTC Perera', 2011), Value : 23
# Index : ('NLTC Perera', 2012), Value : 4
# Index : ('NLTC Perera', 2013), Value : 235
# Index : ('NLTC Perera', 2015), Value : 12
# Index : ('NLTC Perera', 2016), Value : 150
# Index : ('NM Coulter-Nile', 2013), Value : 9
# Index : ('NM Coulter-Nile', 2015), Value : 20
# Index : ('NM Coulter-Nile', 2016), Value : 9
# Index : ('NM Coulter-Nile', 2017), Value : 14
# Index : ('NS Naik', 2016), Value : 23
# Index : ('NV Ojha', 2009), Value : 168
# Index : ('NV Ojha', 2010), Value : 377
# Index : ('NV Ojha', 2011), Value : 160
# Index : ('NV Ojha', 2012), Value : 255
# Index : ('NV Ojha', 2013), Value : 9
# Index : ('NV Ojha', 2014), Value : 232
# Index : ('NV Ojha', 2015), Value : 137
# Index : ('NV Ojha', 2016), Value : 136
# Index : ('NV Ojha', 2017), Value : 79
# Index : ('Niraj Patel', 2008), Value : 103
# Index : ('Niraj Patel', 2009), Value : 18
# Index : ('OA Shah', 2010), Value : 115
# Index : ('OA Shah', 2011), Value : 26
# Index : ('OA Shah', 2012), Value : 340
# Index : ('OA Shah', 2013), Value : 25
# Index : ('P Awana', 2012), Value : 4
# Index : ('P Awana', 2013), Value : 1
# Index : ('P Dogra', 2010), Value : 107
# Index : ('P Dogra', 2012), Value : 15
# Index : ('P Dogra', 2013), Value : 5
# Index : ('P Kumar', 2008), Value : 112
# Index : ('P Kumar', 2009), Value : 65
# Index : ('P Kumar', 2010), Value : 4
# Index : ('P Kumar', 2011), Value : 27
# Index : ('P Kumar', 2012), Value : 35
# Index : ('P Kumar', 2013), Value : 47
# Index : ('P Kumar', 2014), Value : 1
# Index : ('P Kumar', 2015), Value : 17
# Index : ('P Kumar', 2016), Value : 24
# Index : ('P Kumar', 2017), Value : 8
# Index : ('P Negi', 2012), Value : 36
# Index : ('P Negi', 2015), Value : 116
# Index : ('P Negi', 2016), Value : 57
# Index : ('P Negi', 2017), Value : 144
# Index : ('P Parameswaran', 2011), Value : 1
# Index : ('P Parameswaran', 2012), Value : 0
# Index : ('P Sahu', 2016), Value : 19
# Index : ('PA Patel', 2008), Value : 302
# Index : ('PA Patel', 2009), Value : 142
# Index : ('PA Patel', 2010), Value : 72
# Index : ('PA Patel', 2011), Value : 202
# Index : ('PA Patel', 2012), Value : 194
# Index : ('PA Patel', 2013), Value : 294
# Index : ('PA Patel', 2014), Value : 205
# Index : ('PA Patel', 2015), Value : 339
# Index : ('PA Patel', 2016), Value : 177
# Index : ('PA Patel', 2017), Value : 395
# Index : ('PA Reddy', 2012), Value : 73
# Index : ('PA Reddy', 2013), Value : 91
# Index : ('PC Valthaty', 2009), Value : 6
# Index : ('PC Valthaty', 2011), Value : 463
# Index : ('PC Valthaty', 2012), Value : 30
# Index : ('PC Valthaty', 2013), Value : 6
# Index : ('PD Collingwood', 2010), Value : 203
# Index : ('PJ Cummins', 2015), Value : 0
# Index : ('PJ Cummins', 2017), Value : 77
# Index : ('PJ Sangwan', 2008), Value : 2
# Index : ('PJ Sangwan', 2009), Value : 6
# Index : ('PJ Sangwan', 2010), Value : 10
# Index : ('PJ Sangwan', 2013), Value : 4
# Index : ('PJ Sangwan', 2017), Value : 2
# Index : ('PM Sarvesh Kumar', 2008), Value : 1
# Index : ('PP Chawla', 2008), Value : 90
# Index : ('PP Chawla', 2009), Value : 31
# Index : ('PP Chawla', 2010), Value : 62
# Index : ('PP Chawla', 2011), Value : 48
# Index : ('PP Chawla', 2012), Value : 106
# Index : ('PP Chawla', 2013), Value : 64
# Index : ('PP Chawla', 2014), Value : 31
# Index : ('PP Chawla', 2015), Value : 54
# Index : ('PP Chawla', 2016), Value : 27
# Index : ('PP Chawla', 2017), Value : 2
# Index : ('PP Ojha', 2008), Value : 2
# Index : ('PP Ojha', 2009), Value : 1
# Index : ('PP Ojha', 2010), Value : 3
# Index : ('PP Ojha', 2012), Value : 4
# Index : ('PP Ojha', 2013), Value : 2
# Index : ('PP Ojha', 2014), Value : 4
# Index : ('PR Shah', 2008), Value : 34
# Index : ('PR Shah', 2009), Value : 53
# Index : ('PR Shah', 2011), Value : 5
# Index : ('PSP Handscomb', 2016), Value : 6
# Index : ('PV Tambe', 2013), Value : 3
# Index : ('PV Tambe', 2014), Value : 5
# Index : ('PV Tambe', 2015), Value : 3
# Index : ('PV Tambe', 2016), Value : 7
# Index : ('Pankaj Singh', 2008), Value : 5
# Index : ('Pankaj Singh', 2009), Value : 1
# Index : ('Pankaj Singh', 2010), Value : 1
# Index : ('Parvez Rasool', 2013), Value : 5
# Index : ('Parvez Rasool', 2015), Value : 2
# Index : ('Parvez Rasool', 2016), Value : 10
# Index : ('Q de Kock', 2013), Value : 6
# Index : ('Q de Kock', 2014), Value : 153
# Index : ('Q de Kock', 2015), Value : 122
# Index : ('Q de Kock', 2016), Value : 445
# Index : ('R Ashwin', 2009), Value : 8
# Index : ('R Ashwin', 2010), Value : 30
# Index : ('R Ashwin', 2011), Value : 2
# Index : ('R Ashwin', 2012), Value : 18
# Index : ('R Ashwin', 2013), Value : 35
# Index : ('R Ashwin', 2014), Value : 45
# Index : ('R Ashwin', 2015), Value : 52
# Index : ('R Ashwin', 2016), Value : 41
# Index : ('R Bhatia', 2008), Value : 34
# Index : ('R Bhatia', 2009), Value : 8
# Index : ('R Bhatia', 2010), Value : 24
# Index : ('R Bhatia', 2011), Value : 25
# Index : ('R Bhatia', 2012), Value : 35
# Index : ('R Bhatia', 2013), Value : 99
# Index : ('R Bhatia', 2014), Value : 67
# Index : ('R Bhatia', 2015), Value : 0
# Index : ('R Bhatia', 2016), Value : 34
# Index : ('R Bhatia', 2017), Value : 16
# Index : ('R Bishnoi', 2009), Value : 19
# Index : ('R Dhawan', 2013), Value : 21
# Index : ('R Dhawan', 2014), Value : 82
# Index : ('R Dhawan', 2015), Value : 36
# Index : ('R Dhawan', 2016), Value : 14
# Index : ('R Dravid', 2008), Value : 371
# Index : ('R Dravid', 2009), Value : 271
# Index : ('R Dravid', 2010), Value : 256
# Index : ('R Dravid', 2011), Value : 343
# Index : ('R Dravid', 2012), Value : 462
# Index : ('R Dravid', 2013), Value : 471
# Index : ('R McLaren', 2010), Value : 66
# Index : ('R McLaren', 2011), Value : 90
# Index : ('R McLaren', 2013), Value : 3
# Index : ('R Ninan', 2011), Value : 3
# Index : ('R Rampaul', 2013), Value : 38
# Index : ('R Rampaul', 2014), Value : 13
# Index : ('R Sathish', 2010), Value : 112
# Index : ('R Sathish', 2011), Value : 25
# Index : ('R Sathish', 2013), Value : 109
# Index : ('R Sathish', 2016), Value : 24
# Index : ('R Sharma', 2010), Value : 29
# Index : ('R Sharma', 2011), Value : 24
# Index : ('R Sharma', 2012), Value : 2
# Index : ('R Sharma', 2013), Value : 11
# Index : ('R Shukla', 2013), Value : 1
# Index : ('R Shukla', 2014), Value : 18
# Index : ('R Tewatia', 2014), Value : 16
# Index : ('R Tewatia', 2017), Value : 19
# Index : ('R Vinay Kumar', 2008), Value : 25
# Index : ('R Vinay Kumar', 2009), Value : 47
# Index : ('R Vinay Kumar', 2010), Value : 27
# Index : ('R Vinay Kumar', 2011), Value : 50
# Index : ('R Vinay Kumar', 2012), Value : 68
# Index : ('R Vinay Kumar', 2013), Value : 70
# Index : ('R Vinay Kumar', 2014), Value : 4
# Index : ('R Vinay Kumar', 2015), Value : 0
# Index : ('R Vinay Kumar', 2016), Value : 13
# Index : ('RA Jadeja', 2008), Value : 135
# Index : ('RA Jadeja', 2009), Value : 295
# Index : ('RA Jadeja', 2011), Value : 283
# Index : ('RA Jadeja', 2012), Value : 191
# Index : ('RA Jadeja', 2013), Value : 201
# Index : ('RA Jadeja', 2014), Value : 146
# Index : ('RA Jadeja', 2015), Value : 132
# Index : ('RA Jadeja', 2016), Value : 191
# Index : ('RA Jadeja', 2017), Value : 158
# Index : ('RA Tripathi', 2017), Value : 391
# Index : ('RD Chahar', 2017), Value : 3
# Index : ('RE Levi', 2012), Value : 83
# Index : ('RE van der Merwe', 2009), Value : 122
# Index : ('RE van der Merwe', 2010), Value : 1
# Index : ('RE van der Merwe', 2011), Value : 14
# Index : ('RE van der Merwe', 2013), Value : 22
# Index : ('RG More', 2015), Value : 2
# Index : ('RG Sharma', 2008), Value : 404
# Index : ('RG Sharma', 2009), Value : 362
# Index : ('RG Sharma', 2010), Value : 404
# Index : ('RG Sharma', 2011), Value : 372
# Index : ('RG Sharma', 2012), Value : 433
# Index : ('RG Sharma', 2013), Value : 538
# Index : ('RG Sharma', 2014), Value : 390
# Index : ('RG Sharma', 2015), Value : 482
# Index : ('RG Sharma', 2016), Value : 489
# Index : ('RG Sharma', 2017), Value : 333
# Index : ('RJ Harris', 2009), Value : 21
# Index : ('RJ Harris', 2010), Value : 45
# Index : ('RJ Harris', 2011), Value : 31
# Index : ('RJ Harris', 2012), Value : 18
# Index : ('RJ Harris', 2013), Value : 2
# Index : ('RJ Peterson', 2012), Value : 32
# Index : ('RJ Quiney', 2009), Value : 103
# Index : ('RN ten Doeschate', 2011), Value : 107
# Index : ('RN ten Doeschate', 2012), Value : 21
# Index : ('RN ten Doeschate', 2013), Value : 85
# Index : ('RN ten Doeschate', 2014), Value : 52
# Index : ('RN ten Doeschate', 2015), Value : 61
# Index : ('RP Singh', 2008), Value : 27
# Index : ('RP Singh', 2009), Value : 8
# Index : ('RP Singh', 2010), Value : 9
# Index : ('RP Singh', 2011), Value : 2
# Index : ('RP Singh', 2012), Value : 6
# Index : ('RR Bhatkal', 2012), Value : 0
# Index : ('RR Pant', 2016), Value : 198
# Index : ('RR Pant', 2017), Value : 366
# Index : ('RR Powar', 2008), Value : 28
# Index : ('RR Powar', 2009), Value : 23
# Index : ('RR Powar', 2010), Value : 5
# Index : ('RR Powar', 2011), Value : 11
# Index : ('RR Raje', 2008), Value : 8
# Index : ('RR Raje', 2009), Value : 12
# Index : ('RR Rossouw', 2014), Value : 39
# Index : ('RR Rossouw', 2015), Value : 14
# Index : ('RR Sarwan', 2008), Value : 73
# Index : ('RS Bopara', 2009), Value : 138
# Index : ('RS Bopara', 2010), Value : 248
# Index : ('RS Bopara', 2015), Value : 145
# Index : ('RS Gavaskar', 2010), Value : 2
# Index : ('RS Sodhi', 2010), Value : 4
# Index : ('RT Ponting', 2008), Value : 39
# Index : ('RT Ponting', 2013), Value : 52
# Index : ('RV Gomez', 2011), Value : 46
# Index : ('RV Gomez', 2013), Value : 4
# Index : ('RV Uthappa', 2008), Value : 320
# Index : ('RV Uthappa', 2009), Value : 175
# Index : ('RV Uthappa', 2010), Value : 374
# Index : ('RV Uthappa', 2011), Value : 264
# Index : ('RV Uthappa', 2012), Value : 405
# Index : ('RV Uthappa', 2013), Value : 434
# Index : ('RV Uthappa', 2014), Value : 660
# Index : ('RV Uthappa', 2015), Value : 364
# Index : ('RV Uthappa', 2016), Value : 394
# Index : ('RV Uthappa', 2017), Value : 388
# Index : ('Rashid Khan', 2017), Value : 11
# Index : ('S Anirudha', 2008), Value : 1
# Index : ('S Anirudha', 2010), Value : 30
# Index : ('S Anirudha', 2011), Value : 83
# Index : ('S Anirudha', 2012), Value : 19
# Index : ('S Anirudha', 2013), Value : 0
# Index : ('S Anirudha', 2014), Value : 3
# Index : ('S Aravind', 2011), Value : 13
# Index : ('S Aravind', 2012), Value : 14
# Index : ('S Aravind', 2015), Value : 0
# Index : ('S Aravind', 2017), Value : 32
# Index : ('S Badree', 2017), Value : 13
# Index : ('S Badrinath', 2008), Value : 192
# Index : ('S Badrinath', 2009), Value : 177
# Index : ('S Badrinath', 2010), Value : 356
# Index : ('S Badrinath', 2011), Value : 396
# Index : ('S Badrinath', 2012), Value : 196
# Index : ('S Badrinath', 2013), Value : 124
# Index : ('S Chanderpaul', 2008), Value : 25
# Index : ('S Dhawan', 2008), Value : 340
# Index : ('S Dhawan', 2009), Value : 40
# Index : ('S Dhawan', 2010), Value : 191
# Index : ('S Dhawan', 2011), Value : 400
# Index : ('S Dhawan', 2012), Value : 569
# Index : ('S Dhawan', 2013), Value : 311
# Index : ('S Dhawan', 2014), Value : 377
# Index : ('S Dhawan', 2015), Value : 353
# Index : ('S Dhawan', 2016), Value : 501
# Index : ('S Dhawan', 2017), Value : 479
# Index : ('S Gopal', 2014), Value : 11
# Index : ('S Gopal', 2015), Value : 1
# Index : ('S Gopal', 2016), Value : 2
# Index : ('S Kaul', 2013), Value : 7
# Index : ('S Kaul', 2014), Value : 2
# Index : ('S Kaul', 2017), Value : 0
# Index : ('S Kaushik', 2016), Value : 0
# Index : ('S Ladda', 2010), Value : 0
# Index : ('S Nadeem', 2011), Value : 0
# Index : ('S Nadeem', 2012), Value : 0
# Index : ('S Nadeem', 2013), Value : 14
# Index : ('S Nadeem', 2014), Value : 7
# Index : ('S Nadeem', 2015), Value : 2
# Index : ('S Nadeem', 2016), Value : 1
# Index : ('S Nadeem', 2017), Value : 2
# Index : ('S Narwal', 2010), Value : 14
# Index : ('S Narwal', 2013), Value : 23
# Index : ('S Rana', 2011), Value : 18
# Index : ('S Rana', 2014), Value : 73
# Index : ('S Randiv', 2011), Value : 2
# Index : ('S Sohal', 2008), Value : 4
# Index : ('S Sohal', 2009), Value : 115
# Index : ('S Sohal', 2011), Value : 249
# Index : ('S Sreesanth', 2008), Value : 0
# Index : ('S Sreesanth', 2009), Value : 5
# Index : ('S Sreesanth', 2010), Value : 27
# Index : ('S Sreesanth', 2011), Value : 1
# Index : ('S Sreesanth', 2013), Value : 1
# Index : ('S Sriram', 2010), Value : 27
# Index : ('S Sriram', 2011), Value : 4
# Index : ('S Tyagi', 2010), Value : 3
# Index : ('S Vidyut', 2008), Value : 145
# Index : ('SA Abbott', 2015), Value : 15
# Index : ('SA Asnodkar', 2008), Value : 311
# Index : ('SA Asnodkar', 2009), Value : 98
# Index : ('SA Asnodkar', 2010), Value : 5
# Index : ('SA Asnodkar', 2011), Value : 9
# Index : ('SA Yadav', 2012), Value : 0
# Index : ('SA Yadav', 2014), Value : 164
# Index : ('SA Yadav', 2015), Value : 157
# Index : ('SA Yadav', 2016), Value : 182
# Index : ('SA Yadav', 2017), Value : 105
# Index : ('SB Bangar', 2008), Value : 47
# Index : ('SB Bangar', 2009), Value : 2
# Index : ('SB Jakati', 2009), Value : 20
# Index : ('SB Jakati', 2012), Value : 7
# Index : ('SB Jakati', 2016), Value : 1
# Index : ('SB Joshi', 2008), Value : 6
# Index : ('SB Styris', 2008), Value : 112
# Index : ('SB Styris', 2009), Value : 14
# Index : ('SB Styris', 2011), Value : 5
# Index : ('SB Wagh', 2011), Value : 2
# Index : ('SC Ganguly', 2008), Value : 349
# Index : ('SC Ganguly', 2009), Value : 189
# Index : ('SC Ganguly', 2010), Value : 493
# Index : ('SC Ganguly', 2011), Value : 50
# Index : ('SC Ganguly', 2012), Value : 268
# Index : ('SD Chitnis', 2008), Value : 18
# Index : ('SD Chitnis', 2009), Value : 6
# Index : ('SD Chitnis', 2011), Value : 9
# Index : ('SD Chitnis', 2012), Value : 66
# Index : ('SE Bond', 2010), Value : 1
# Index : ('SE Marsh', 2008), Value : 616
# Index : ('SE Marsh', 2010), Value : 147
# Index : ('SE Marsh', 2011), Value : 504
# Index : ('SE Marsh', 2012), Value : 336
# Index : ('SE Marsh', 2013), Value : 300
# Index : ('SE Marsh', 2014), Value : 70
# Index : ('SE Marsh', 2015), Value : 93
# Index : ('SE Marsh', 2016), Value : 159
# Index : ('SE Marsh', 2017), Value : 264
# Index : ('SJ Srivastava', 2010), Value : 1
# Index : ('SJ Srivastava', 2011), Value : 4
# Index : ('SK Raina', 2008), Value : 421
# Index : ('SK Raina', 2009), Value : 434
# Index : ('SK Raina', 2010), Value : 528
# Index : ('SK Raina', 2011), Value : 438
# Index : ('SK Raina', 2012), Value : 441
# Index : ('SK Raina', 2013), Value : 548
# Index : ('SK Raina', 2014), Value : 523
# Index : ('SK Raina', 2015), Value : 374
# Index : ('SK Raina', 2016), Value : 399
# Index : ('SK Raina', 2017), Value : 442
# Index : ('SK Trivedi', 2008), Value : 5
# Index : ('SK Trivedi', 2009), Value : 9
# Index : ('SK Trivedi', 2010), Value : 20
# Index : ('SK Trivedi', 2011), Value : 0
# Index : ('SK Trivedi', 2012), Value : 5
# Index : ('SK Trivedi', 2013), Value : 3
# Index : ('SK Warne', 2008), Value : 70
# Index : ('SK Warne', 2009), Value : 108
# Index : ('SK Warne', 2010), Value : 10
# Index : ('SK Warne', 2011), Value : 10
# Index : ('SL Malinga', 2009), Value : 0
# Index : ('SL Malinga', 2010), Value : 1
# Index : ('SL Malinga', 2011), Value : 8
# Index : ('SL Malinga', 2012), Value : 55
# Index : ('SL Malinga', 2013), Value : 9
# Index : ('SL Malinga', 2014), Value : 2
# Index : ('SL Malinga', 2015), Value : 6
# Index : ('SL Malinga', 2017), Value : 7
# Index : ('SM Harwood', 2009), Value : 9
# Index : ('SM Katich', 2008), Value : 96
# Index : ('SM Katich', 2009), Value : 145
# Index : ('SM Pollock', 2008), Value : 147
# Index : ('SMSM Senanayake', 2013), Value : 10
# Index : ('SN Khan', 2015), Value : 111
# Index : ('SN Khan', 2016), Value : 66
# Index : ('SN Thakur', 2015), Value : 7
# Index : ('SN Thakur', 2017), Value : 0
# Index : ('SP Fleming', 2008), Value : 196
# Index : ('SP Goswami', 2008), Value : 82
# Index : ('SP Goswami', 2009), Value : 53
# Index : ('SP Goswami', 2010), Value : 8
# Index : ('SP Goswami', 2011), Value : 29
# Index : ('SP Goswami', 2012), Value : 69
# Index : ('SP Jackson', 2017), Value : 38
# Index : ('SP Narine', 2012), Value : 9
# Index : ('SP Narine', 2013), Value : 21
# Index : ('SP Narine', 2014), Value : 10
# Index : ('SP Narine', 2015), Value : 0
# Index : ('SP Narine', 2016), Value : 7
# Index : ('SP Narine', 2017), Value : 224
# Index : ('SPD Smith', 2012), Value : 362
# Index : ('SPD Smith', 2013), Value : 159
# Index : ('SPD Smith', 2014), Value : 152
# Index : ('SPD Smith', 2015), Value : 298
# Index : ('SPD Smith', 2016), Value : 270
# Index : ('SPD Smith', 2017), Value : 472
# Index : ('SR Tendulkar', 2008), Value : 188
# Index : ('SR Tendulkar', 2009), Value : 364
# Index : ('SR Tendulkar', 2010), Value : 618
# Index : ('SR Tendulkar', 2011), Value : 553
# Index : ('SR Tendulkar', 2012), Value : 324
# Index : ('SR Tendulkar', 2013), Value : 287
# Index : ('SR Watson', 2008), Value : 472
# Index : ('SR Watson', 2010), Value : 185
# Index : ('SR Watson', 2011), Value : 330
# Index : ('SR Watson', 2012), Value : 255
# Index : ('SR Watson', 2013), Value : 543
# Index : ('SR Watson', 2014), Value : 246
# Index : ('SR Watson', 2015), Value : 347
# Index : ('SR Watson', 2016), Value : 179
# Index : ('SR Watson', 2017), Value : 71
# Index : ('SS Iyer', 2015), Value : 439
# Index : ('SS Iyer', 2016), Value : 30
# Index : ('SS Iyer', 2017), Value : 338
# Index : ('SS Shaikh', 2009), Value : 6
# Index : ('SS Tiwary', 2008), Value : 26
# Index : ('SS Tiwary', 2009), Value : 13
# Index : ('SS Tiwary', 2010), Value : 419
# Index : ('SS Tiwary', 2011), Value : 187
# Index : ('SS Tiwary', 2012), Value : 191
# Index : ('SS Tiwary', 2013), Value : 109
# Index : ('SS Tiwary', 2015), Value : 109
# Index : ('SS Tiwary', 2016), Value : 170
# Index : ('SS Tiwary', 2017), Value : 52
# Index : ('ST Jayasuriya', 2008), Value : 514
# Index : ('ST Jayasuriya', 2009), Value : 221
# Index : ('ST Jayasuriya', 2010), Value : 33
# Index : ('STR Binny', 2010), Value : 8
# Index : ('STR Binny', 2011), Value : 37
# Index : ('STR Binny', 2012), Value : 90
# Index : ('STR Binny', 2013), Value : 293
# Index : ('STR Binny', 2014), Value : 123
# Index : ('STR Binny', 2015), Value : 74
# Index : ('STR Binny', 2016), Value : 63
# Index : ('STR Binny', 2017), Value : 78
# Index : ('SV Samson', 2013), Value : 206
# Index : ('SV Samson', 2014), Value : 339
# Index : ('SV Samson', 2015), Value : 204
# Index : ('SV Samson', 2016), Value : 291
# Index : ('SV Samson', 2017), Value : 386
# Index : ('SW Billings', 2016), Value : 88
# Index : ('SW Billings', 2017), Value : 138
# Index : ('SW Tait', 2010), Value : 12
# Index : ('SW Tait', 2011), Value : 10
# Index : ('SW Tait', 2013), Value : 1
# Index : ('Sachin Baby', 2013), Value : 3
# Index : ('Sachin Baby', 2016), Value : 119
# Index : ('Sachin Baby', 2017), Value : 15
# Index : ('Salman Butt', 2008), Value : 193
# Index : ('Sandeep Sharma', 2013), Value : 0
# Index : ('Sandeep Sharma', 2014), Value : 2
# Index : ('Sandeep Sharma', 2015), Value : 9
# Index : ('Sandeep Sharma', 2016), Value : 8
# Index : ('Sandeep Sharma', 2017), Value : 7
# Index : ('Shahid Afridi', 2008), Value : 81
# Index : ('Shakib Al Hasan', 2011), Value : 29
# Index : ('Shakib Al Hasan', 2012), Value : 91
# Index : ('Shakib Al Hasan', 2014), Value : 229
# Index : ('Shakib Al Hasan', 2015), Value : 36
# Index : ('Shakib Al Hasan', 2016), Value : 114
# Index : ('Shakib Al Hasan', 2017), Value : 1
# Index : ('Shivam Sharma', 2014), Value : 5
# Index : ('Shoaib Ahmed', 2009), Value : 1
# Index : ('Shoaib Akhtar', 2008), Value : 2
# Index : ('Shoaib Malik', 2008), Value : 52
# Index : ('Sohail Tanvir', 2008), Value : 36
# Index : ('Sunny Gupta', 2012), Value : 0
# Index : ('Sunny Singh', 2011), Value : 43
# Index : ('Swapnil Singh', 2016), Value : 0
# Index : ('Swapnil Singh', 2017), Value : 12
# Index : ('T Henderson', 2009), Value : 11
# Index : ('T Kohli', 2008), Value : 10
# Index : ('T Kohli', 2009), Value : 1
# Index : ('T Taibu', 2008), Value : 31
# Index : ('T Thushara', 2009), Value : 2
# Index : ('T Thushara', 2010), Value : 10
# Index : ('TA Boult', 2017), Value : 5
# Index : ('TD Paine', 2011), Value : 10
# Index : ('TG Southee', 2014), Value : 4
# Index : ('TG Southee', 2015), Value : 13
# Index : ('TG Southee', 2016), Value : 30
# Index : ('TG Southee', 2017), Value : 7
# Index : ('TL Suman', 2009), Value : 237
# Index : ('TL Suman', 2010), Value : 307
# Index : ('TL Suman', 2011), Value : 65
# Index : ('TL Suman', 2012), Value : 15
# Index : ('TL Suman', 2013), Value : 52
# Index : ('TM Dilshan', 2008), Value : 104
# Index : ('TM Dilshan', 2009), Value : 418
# Index : ('TM Dilshan', 2010), Value : 44
# Index : ('TM Dilshan', 2011), Value : 226
# Index : ('TM Dilshan', 2012), Value : 285
# Index : ('TM Dilshan', 2013), Value : 76
# Index : ('TM Head', 2016), Value : 54
# Index : ('TM Head', 2017), Value : 151
# Index : ('TM Srivastava', 2008), Value : 8
# Index : ('TM Srivastava', 2009), Value : 0
# Index : ('TR Birt', 2011), Value : 75
# Index : ('TS Mills', 2017), Value : 8
# Index : ('U Kaul', 2008), Value : 0
# Index : ('UA Birla', 2013), Value : 7
# Index : ('UBT Chand', 2011), Value : 2
# Index : ('UBT Chand', 2012), Value : 36
# Index : ('UBT Chand', 2013), Value : 158
# Index : ('UBT Chand', 2014), Value : 2
# Index : ('UBT Chand', 2015), Value : 102
# Index : ('UBT Chand', 2016), Value : 0
# Index : ('UT Khawaja', 2016), Value : 127
# Index : ('UT Yadav', 2010), Value : 3
# Index : ('UT Yadav', 2011), Value : 1
# Index : ('UT Yadav', 2012), Value : 2
# Index : ('UT Yadav', 2013), Value : 38
# Index : ('UT Yadav', 2014), Value : 2
# Index : ('UT Yadav', 2015), Value : 29
# Index : ('UT Yadav', 2016), Value : 9
# Index : ('UT Yadav', 2017), Value : 10
# Index : ('Umar Gul', 2008), Value : 39
# Index : ('V Kohli', 2008), Value : 165
# Index : ('V Kohli', 2009), Value : 246
# Index : ('V Kohli', 2010), Value : 307
# Index : ('V Kohli', 2011), Value : 557
# Index : ('V Kohli', 2012), Value : 364
# Index : ('V Kohli', 2013), Value : 639
# Index : ('V Kohli', 2014), Value : 359
# Index : ('V Kohli', 2015), Value : 505
# Index : ('V Kohli', 2016), Value : 973
# Index : ('V Kohli', 2017), Value : 308
# Index : ('V Pratap Singh', 2012), Value : 0
# Index : ('V Sehwag', 2008), Value : 406
# Index : ('V Sehwag', 2009), Value : 198
# Index : ('V Sehwag', 2010), Value : 356
# Index : ('V Sehwag', 2011), Value : 424
# Index : ('V Sehwag', 2012), Value : 495
# Index : ('V Sehwag', 2013), Value : 295
# Index : ('V Sehwag', 2014), Value : 455
# Index : ('V Sehwag', 2015), Value : 99
# Index : ('V Shankar', 2017), Value : 101
# Index : ('VH Zol', 2014), Value : 29
# Index : ('VR Aaron', 2011), Value : 0
# Index : ('VR Aaron', 2012), Value : 1
# Index : ('VR Aaron', 2014), Value : 35
# Index : ('VR Aaron', 2015), Value : 6
# Index : ('VR Aaron', 2017), Value : 4
# Index : ('VRV Singh', 2008), Value : 4
# Index : ('VS Malik', 2010), Value : 6
# Index : ('VS Malik', 2014), Value : 1
# Index : ('VS Yeligati', 2008), Value : 2
# Index : ('VVS Laxman', 2008), Value : 155
# Index : ('VVS Laxman', 2009), Value : 19
# Index : ('VVS Laxman', 2010), Value : 64
# Index : ('VVS Laxman', 2011), Value : 44
# Index : ('VY Mahesh', 2008), Value : 15
# Index : ('Vishnu Vinod', 2017), Value : 19
# Index : ('W Jaffer', 2008), Value : 115
# Index : ('W Jaffer', 2009), Value : 15
# Index : ('WA Mota', 2008), Value : 26
# Index : ('WA Mota', 2009), Value : 30
# Index : ('WD Parnell', 2011), Value : 37
# Index : ('WD Parnell', 2012), Value : 19
# Index : ('WD Parnell', 2013), Value : 5
# Index : ('WD Parnell', 2014), Value : 2
# Index : ('WP Saha', 2008), Value : 159
# Index : ('WP Saha', 2009), Value : 72
# Index : ('WP Saha', 2010), Value : 67
# Index : ('WP Saha', 2011), Value : 68
# Index : ('WP Saha', 2012), Value : 6
# Index : ('WP Saha', 2013), Value : 70
# Index : ('WP Saha', 2014), Value : 362
# Index : ('WP Saha', 2015), Value : 249
# Index : ('WP Saha', 2016), Value : 270
# Index : ('WP Saha', 2017), Value : 234
# Index : ('WPUJC Vaas', 2008), Value : 21
# Index : ('WPUJC Vaas', 2009), Value : 30
# Index : ('WPUJC Vaas', 2010), Value : 30
# Index : ('Washington Sundar', 2017), Value : 9
# Index : ('X Thalaivan Sargunam', 2013), Value : 10
# Index : ('Y Gnaneswara Rao', 2011), Value : 19
# Index : ('Y Nagar', 2009), Value : 20
# Index : ('Y Nagar', 2010), Value : 1
# Index : ('Y Nagar', 2011), Value : 111
# Index : ('Y Nagar', 2012), Value : 153
# Index : ('Y Venugopal Rao', 2008), Value : 288
# Index : ('Y Venugopal Rao', 2009), Value : 124
# Index : ('Y Venugopal Rao', 2010), Value : 34
# Index : ('Y Venugopal Rao', 2011), Value : 336
# Index : ('Y Venugopal Rao', 2012), Value : 132
# Index : ('Y Venugopal Rao', 2014), Value : 71
# Index : ('YA Abdulla', 2010), Value : 0
# Index : ('YK Pathan', 2008), Value : 435
# Index : ('YK Pathan', 2009), Value : 261
# Index : ('YK Pathan', 2010), Value : 333
# Index : ('YK Pathan', 2011), Value : 283
# Index : ('YK Pathan', 2012), Value : 194
# Index : ('YK Pathan', 2013), Value : 332
# Index : ('YK Pathan', 2014), Value : 268
# Index : ('YK Pathan', 2015), Value : 312
# Index : ('YK Pathan', 2016), Value : 361
# Index : ('YK Pathan', 2017), Value : 143
# Index : ('YS Chahal', 2014), Value : 1
# Index : ('YS Chahal', 2015), Value : 1
# Index : ('YS Chahal', 2017), Value : 13
# Index : ('YV Takawale', 2008), Value : 70
# Index : ('YV Takawale', 2009), Value : 18
# Index : ('YV Takawale', 2014), Value : 104
# Index : ('Yashpal Singh', 2009), Value : 47
# Index : ('Younis Khan', 2008), Value : 3
# Index : ('Yuvraj Singh', 2008), Value : 299
# Index : ('Yuvraj Singh', 2009), Value : 340
# Index : ('Yuvraj Singh', 2010), Value : 259
# Index : ('Yuvraj Singh', 2011), Value : 343
# Index : ('Yuvraj Singh', 2013), Value : 238
# Index : ('Yuvraj Singh', 2014), Value : 376
# Index : ('Yuvraj Singh', 2015), Value : 248
# Index : ('Yuvraj Singh', 2016), Value : 236
# Index : ('Yuvraj Singh', 2017), Value : 252
# Index : ('Z Khan', 2008), Value : 34
# Index : ('Z Khan', 2009), Value : 8
# Index : ('Z Khan', 2010), Value : 24
# Index : ('Z Khan', 2011), Value : 21
# Index : ('Z Khan', 2012), Value : 12
# Index : ('Z Khan', 2014), Value : 8
# Index : ('Z Khan', 2016), Value : 6
# Index : ('Z Khan', 2017), Value : 4

# %%
#To check who is the Most consistent Batsman among top 5
top_five = df.groupby('batsman')['batsman_runs'].sum().nlargest(5)
grp = final_data.groupby(['match_id','batsman'])['batsman_runs'].sum().reset_index()
batsman_innings = {}
for index,row in grp.iterrows():
    if row['batsman'] in top_five.index:
        if row['batsman'] in batsman_innings:
            batsman_innings[row['batsman']].append(row['batsman_runs'])
        else:
            batsman_innings[row['batsman']] = [row['batsman_runs']]
                
#fig, ax = plt.subplots(len(batsman_innings), 1, figsize=(7,50))\n",
#for ax,key in zip(ax,batsman_innings.keys()):\n",
#y = batsman_innings[key]\n",
#sns.distplot(y,ax = ax,hist=False,label=key)\n",
plt.figure(8)
fig, ax = plt.subplots()
fig.set_size_inches(13, 7)
for key,value in batsman_innings.items():
    sns.distplot(value,hist=False,label=key)

# %%
#Top Wicket-Takers in all season
d = final_data[final_data['dismissal_kind'] != 'run out'] 
top_bowler = d.groupby('bowler')['player_dismissed'].count().nlargest(10)
plt.figure(5)
fig, ax = plt.subplots()
fig.set_size_inches(13, 5)
plt.title('Top Wicket Takers')
plt.xlabel('Bowler')
plt.ylabel('Wickets')
plt.xticks(rotation=20)
sns.barplot(x=top_bowler.index,y=top_bowler.values)

# %%
top_bowler_by_season = d.groupby(['bowler','season'])['player_dismissed'].count().nlargest(10)
#Top Wicket-Takers in all season
plt.figure(5)
fig, ax = plt.subplots()
fig.set_size_inches(13, 5)
plt.title('Top Wicket Takers in every season')
plt.ylabel('Wickets')
plt.xticks(rotation=20)
sns.barplot(x=top_bowler_by_season.index,y=top_bowler_by_season.values)

# %%
top = final_data.groupby(['batsman','season'])['batsman_runs'].sum()
highest_run_getters = top.groupby(level='season').nlargest(10)
#highest_run_getters

# %%
only_sixes = final_data[final_data['batsman_runs'] == 6]
most_sixes =  only_sixes.groupby(['batsman'])['batsman_runs'].count().nlargest(15)
most_sixes

# %%
#Highest Strike Rate
runs = df.groupby('batsman')['batsman_runs'].sum()
num_of_del = df.groupby('batsman')['batsman_runs'].count()
min_500 = num_of_del[num_of_del >= 500]
max_SR = (runs / min_500)*100
max_SR.nlargest(15)

# %%
#Most Economical Bowlers
total_runs = final_data.groupby('bowler')['total_runs'].sum()
number_of_del = final_data.groupby('bowler')['total_runs'].count()
min_100 = number_of_del[number_of_del >= 500]
min_Eco = (total_runs / min_100)*6
min_Eco.nsmallest(15)

# %%
#Type of dismissals for top bowlers
top_bowler = d.groupby('bowler')['player_dismissed'].count().nlargest(10)
type_dismiss = final_data.groupby('bowler')['dismissal_kind'].value_counts()
bowler_dismiss = type_dismiss[list(top_bowler.index)]
index = bowler_dismiss.index.get_level_values(0).unique()
fig = plt.figure(figsize=(15,35))
fig.subplots_adjust(hspace=0.3, wspace=0.3)
for value,i in zip(index,range(1,len(index)+1)):
    plt.subplot(5,2,i)
    plt.title(value)
    plt.pie(bowler_dismiss[value],labels = bowler_dismiss[value].index)
